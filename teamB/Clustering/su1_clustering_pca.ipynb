# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 수1

# %% [markdown]
# ## 결측치=0 kmeans

# %%
s1 = pd.read_csv('/content/drive/MyDrive/프리윌린/su1_column_115.csv')

# %%
su1_table = s1.iloc[:,1:]

# %%
su1_table
# Out:
#          3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 0      0.785218  0.481168  0.170512 -1.117303       NaN -0.667929 -0.824468
# 1           NaN  0.583883  0.114975  0.053498  2.077496       NaN -0.247911
# 2      0.448712  0.326945 -0.775063  0.163261       NaN -0.091704  0.314965
# 3           NaN       NaN       NaN -0.733134 -0.444662  0.785159 -0.531755
# 4      0.785218       NaN  1.474754  0.979621  0.714375       NaN  1.029385
# ...         ...       ...       ...       ...       ...       ...       ...
# 17438       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 17439       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 17440       NaN       NaN  1.474754 -2.141754  2.077496       NaN       NaN
# 17441       NaN       NaN  1.474754 -2.141754  2.077496       NaN       NaN
# 17442       NaN       NaN  1.474754 -2.141754  2.077496       NaN       NaN
#
# ...

# %%
su1_table.fillna(0,inplace=True)
su1_table.head(3)
#처음에 원래 223개 column
# Out:
#      3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 0  0.785218  0.481168  0.170512 -1.117303  0.000000 -0.667929 -0.824468
# 1  0.000000  0.583883  0.114975  0.053498  2.077496  0.000000 -0.247911
# 2  0.448712  0.326945 -0.775063  0.163261  0.000000 -0.091704  0.314965
#
#      3381_3    3381_4  3381_5  ...    3403_1    3403_2    3403_3    3403_4  \
# 0  0.107157  0.539246     0.0  ... -2.032468 -0.695463  0.464646  0.137118
# 1  0.466481  0.655537     0.0  ... -0.238156  0.388670  0.485794  0.123795
# 2  0.557257  0.000000     0.0  ... -0.120035  0.087035 -0.231018 -0.258156
#
#      3403_5    3404_1    3404_2    3404_3    3404_4    3404_5
# 0  0.000000 -1.593239 -0.202572  0.448705 -0.291084 -1.395543
# 1 -0.284755  0.000000  0.476071  0.318606 -0.175488  0.117922
# 2  0.000000 -0.076798  0.116851 -0.071692 -0.536725  0.000000
#
# [3 rows x 115 columns]

# %% [markdown]
# ### k=2,3,4,5에 따른 클러스터 분류

# %%
from sklearn.cluster import KMeans

# %%
original_su1=su1_table

# %%
#2개의 집단으로 구분함
su1_kmeans2=su1_table.copy(deep=False)
km = KMeans(n_clusters=2,  #cluster 개수
           init='random',
           n_init=10,
           max_iter=300,
           tol=1e-04, 
           random_state=0)

y_km=km.fit_predict(su1_kmeans2)
su1_kmeans2['y_km']=y_km.tolist()
su1_kmeans2.head(3)
# Out:
#      3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 0  0.785218  0.481168  0.170512 -1.117303  0.000000 -0.667929 -0.824468
# 1  0.000000  0.583883  0.114975  0.053498  2.077496  0.000000 -0.247911
# 2  0.448712  0.326945 -0.775063  0.163261  0.000000 -0.091704  0.314965
#
#      3381_3    3381_4  3381_5  ...    3403_2    3403_3    3403_4    3403_5  \
# 0  0.107157  0.539246     0.0  ... -0.695463  0.464646  0.137118  0.000000
# 1  0.466481  0.655537     0.0  ...  0.388670  0.485794  0.123795 -0.284755
# 2  0.557257  0.000000     0.0  ...  0.087035 -0.231018 -0.258156  0.000000
#
#      3404_1    3404_2    3404_3    3404_4    3404_5  y_km
# 0 -1.593239 -0.202572  0.448705 -0.291084 -1.395543     1
# 1  0.000000  0.476071  0.318606 -0.175488  0.117922     0
# 2 -0.076798  0.116851 -0.071692 -0.536725  0.000000     1
#
# [3 rows x 116 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_transformed = pca.fit_transform(su1_table)

su1_kmeans2['pca_x'] = pca_transformed[:,0]
su1_kmeans2['pca_y'] = pca_transformed[:,1]
su1_kmeans2.head(3)
# Out:
#      3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 0  0.785218  0.481168  0.170512 -1.117303  0.000000 -0.667929 -0.824468
# 1  0.000000  0.583883  0.114975  0.053498  2.077496  0.000000 -0.247911
# 2  0.448712  0.326945 -0.775063  0.163261  0.000000 -0.091704  0.314965
#
#      3381_3    3381_4  3381_5  ...    3403_4    3403_5    3404_1    3404_2  \
# 0  0.107157  0.539246     0.0  ...  0.137118  0.000000 -1.593239 -0.202572
# 1  0.466481  0.655537     0.0  ...  0.123795 -0.284755  0.000000  0.476071
# 2  0.557257  0.000000     0.0  ... -0.258156  0.000000 -0.076798  0.116851
#
#      3404_3    3404_4    3404_5  y_km     pca_x     pca_y
# 0  0.448705 -0.291084 -1.395543     1  1.508997  2.472609
# 1  0.318606 -0.175488  0.117922     0 -2.307286  0.157064
# 2 -0.071692 -0.536725  0.000000     1  2.625383 -2.678102
#
# [3 rows x 118 columns]

# %%
sns.scatterplot(x='pca_x', y='pca_y', hue='y_km', style='y_km', s=100, data=su1_kmeans2)

# %%
#3개의 집단으로 구분함
su1_kmeans3=su1_table.copy(deep=False)
from sklearn.cluster import KMeans
km = KMeans(n_clusters=3,  #cluster 개수
           init='random',
           n_init=10,
           max_iter=300,
           tol=1e-04, 
           random_state=0)

y_km=km.fit_predict(su1_kmeans3)
su1_kmeans3['y_km']=y_km.tolist()
su1_kmeans3.head(3)
# Out:
#      3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 0  0.785218  0.481168  0.170512 -1.117303  0.000000 -0.667929 -0.824468
# 1  0.000000  0.583883  0.114975  0.053498  2.077496  0.000000 -0.247911
# 2  0.448712  0.326945 -0.775063  0.163261  0.000000 -0.091704  0.314965
#
#      3381_3    3381_4  3381_5  ...    3403_2    3403_3    3403_4    3403_5  \
# 0  0.107157  0.539246     0.0  ... -0.695463  0.464646  0.137118  0.000000
# 1  0.466481  0.655537     0.0  ...  0.388670  0.485794  0.123795 -0.284755
# 2  0.557257  0.000000     0.0  ...  0.087035 -0.231018 -0.258156  0.000000
#
#      3404_1    3404_2    3404_3    3404_4    3404_5  y_km
# 0 -1.593239 -0.202572  0.448705 -0.291084 -1.395543     2
# 1  0.000000  0.476071  0.318606 -0.175488  0.117922     1
# 2 -0.076798  0.116851 -0.071692 -0.536725  0.000000     2
#
# [3 rows x 116 columns]

# %%
su1_kmeans3['pca_x'] = pca_transformed[:,0]
su1_kmeans3['pca_y'] = pca_transformed[:,1]
su1_kmeans3.head(3)
# Out:
#      3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 0  0.785218  0.481168  0.170512 -1.117303  0.000000 -0.667929 -0.824468
# 1  0.000000  0.583883  0.114975  0.053498  2.077496  0.000000 -0.247911
# 2  0.448712  0.326945 -0.775063  0.163261  0.000000 -0.091704  0.314965
#
#      3381_3    3381_4  3381_5  ...    3403_4    3403_5    3404_1    3404_2  \
# 0  0.107157  0.539246     0.0  ...  0.137118  0.000000 -1.593239 -0.202572
# 1  0.466481  0.655537     0.0  ...  0.123795 -0.284755  0.000000  0.476071
# 2  0.557257  0.000000     0.0  ... -0.258156  0.000000 -0.076798  0.116851
#
#      3404_3    3404_4    3404_5  y_km     pca_x     pca_y
# 0  0.448705 -0.291084 -1.395543     2  1.508997  2.472609
# 1  0.318606 -0.175488  0.117922     1 -2.307286  0.157064
# 2 -0.071692 -0.536725  0.000000     2  2.625383 -2.678102
#
# [3 rows x 118 columns]

# %%
sns.scatterplot(x='pca_x', y='pca_y', hue='y_km', style='y_km', s=100, data=su1_kmeans3)

# %%
su1_kmeans4=su1_table.copy(deep=False)
from sklearn.cluster import KMeans
km = KMeans(n_clusters=4,  #cluster 개수
           init='random',
           n_init=10,
           max_iter=1000,
           tol=1e-04, 
           random_state=0)

y_km=km.fit_predict(su1_kmeans4)
su1_kmeans4['y_km']=y_km.tolist()
su1_kmeans4.head(3)
# Out:
#      3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 0  0.785218  0.481168  0.170512 -1.117303  0.000000 -0.667929 -0.824468
# 1  0.000000  0.583883  0.114975  0.053498  2.077496  0.000000 -0.247911
# 2  0.448712  0.326945 -0.775063  0.163261  0.000000 -0.091704  0.314965
#
#      3381_3    3381_4  3381_5  ...    3403_2    3403_3    3403_4    3403_5  \
# 0  0.107157  0.539246     0.0  ... -0.695463  0.464646  0.137118  0.000000
# 1  0.466481  0.655537     0.0  ...  0.388670  0.485794  0.123795 -0.284755
# 2  0.557257  0.000000     0.0  ...  0.087035 -0.231018 -0.258156  0.000000
#
#      3404_1    3404_2    3404_3    3404_4    3404_5  y_km
# 0 -1.593239 -0.202572  0.448705 -0.291084 -1.395543     3
# 1  0.000000  0.476071  0.318606 -0.175488  0.117922     1
# 2 -0.076798  0.116851 -0.071692 -0.536725  0.000000     3
#
# [3 rows x 116 columns]

# %%
su1_kmeans4['pca_x'] = pca_transformed[:,0]
su1_kmeans4['pca_y'] = pca_transformed[:,1]
sns.scatterplot(x='pca_x', y='pca_y', hue='y_km', style='y_km', s=100, data=su1_kmeans4)

# %%
su1_kmeans5=su1_table.copy(deep=False)
from sklearn.cluster import KMeans
km = KMeans(n_clusters=5,  #cluster 개수
           init='random',
           n_init=10,
           max_iter=300,
           tol=1e-04, 
           random_state=0)

y_km=km.fit_predict(su1_kmeans5)
su1_kmeans5['y_km']=y_km.tolist()
su1_kmeans5.head(3)
# Out:
#      3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 0  0.785218  0.481168  0.170512 -1.117303  0.000000 -0.667929 -0.824468
# 1  0.000000  0.583883  0.114975  0.053498  2.077496  0.000000 -0.247911
# 2  0.448712  0.326945 -0.775063  0.163261  0.000000 -0.091704  0.314965
#
#      3381_3    3381_4  3381_5  ...    3403_2    3403_3    3403_4    3403_5  \
# 0  0.107157  0.539246     0.0  ... -0.695463  0.464646  0.137118  0.000000
# 1  0.466481  0.655537     0.0  ...  0.388670  0.485794  0.123795 -0.284755
# 2  0.557257  0.000000     0.0  ...  0.087035 -0.231018 -0.258156  0.000000
#
#      3404_1    3404_2    3404_3    3404_4    3404_5  y_km
# 0 -1.593239 -0.202572  0.448705 -0.291084 -1.395543     3
# 1  0.000000  0.476071  0.318606 -0.175488  0.117922     2
# 2 -0.076798  0.116851 -0.071692 -0.536725  0.000000     1
#
# [3 rows x 116 columns]

# %%
su1_kmeans5['pca_x'] = pca_transformed[:,0]
su1_kmeans5['pca_y'] = pca_transformed[:,1]
sns.scatterplot(x='pca_x', y='pca_y', hue='y_km', style='y_km', s=100, data=su1_kmeans5)

# %%
su1_kmeans6=su1_table.copy(deep=False)
from sklearn.cluster import KMeans
km = KMeans(n_clusters=6,  #cluster 개수
           init='random',
           n_init=10,
           max_iter=1000,
           tol=1e-04, 
           random_state=0)

y_km=km.fit_predict(su1_kmeans6)
su1_kmeans6['y_km']=y_km.tolist()
su1_kmeans6.head(3)
# Out:
#      3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 0  0.785218  0.481168  0.170512 -1.117303  0.000000 -0.667929 -0.824468
# 1  0.000000  0.583883  0.114975  0.053498  2.077496  0.000000 -0.247911
# 2  0.448712  0.326945 -0.775063  0.163261  0.000000 -0.091704  0.314965
#
#      3381_3    3381_4  3381_5  ...    3403_2    3403_3    3403_4    3403_5  \
# 0  0.107157  0.539246     0.0  ... -0.695463  0.464646  0.137118  0.000000
# 1  0.466481  0.655537     0.0  ...  0.388670  0.485794  0.123795 -0.284755
# 2  0.557257  0.000000     0.0  ...  0.087035 -0.231018 -0.258156  0.000000
#
#      3404_1    3404_2    3404_3    3404_4    3404_5  y_km
# 0 -1.593239 -0.202572  0.448705 -0.291084 -1.395543     3
# 1  0.000000  0.476071  0.318606 -0.175488  0.117922     2
# 2 -0.076798  0.116851 -0.071692 -0.536725  0.000000     1
#
# [3 rows x 116 columns]

# %% [markdown]
# ### 실루엣 분석 진행
# - 실루엣 계수 = 개별 데이터가 같은 군집 내의 데이터와 얼마나 가깝고, 다른 군집의 데이터와 얼마나 분리되어 있는지를 나타내는 지표
# - 1에 가까울수록 잘 분리
# - 음수면 같은 군집 데이터보다 다른 군집의 데이터가 더 가깝다는 의미(군집화 잘못됨)

# %%
su1_table.head(3)
# Out:
# curri_level    3380_1    3380_2    3380_3    3380_4    3380_5    3381_1  \
# student_id
# I100008      0.785218  0.481168  0.170512 -1.117303 -6.000000 -0.667929
# I100067     -6.000000  0.583883  0.114975  0.053498  2.077496 -6.000000
# I100168      0.448712  0.326945 -0.775063  0.163261 -6.000000 -0.091704
#
# curri_level    3381_2    3381_3    3381_4  3381_5  ...  3528_2  3528_3  \
# student_id                                         ...
# I100008     -0.824468  0.107157  0.539246    -6.0  ...    -6.0    -6.0
# I100067     -0.247911  0.466481  0.655537    -6.0  ...    -6.0    -6.0
# I100168      0.314965  0.557257 -6.000000    -6.0  ...    -6.0    -6.0
#
# curri_level  3528_4  3532_2  3534_2  3534_3  3534_4  3535_3  3535_4  3535_5
# student_id
# I100008        -6.0    -6.0    -6.0    -6.0    -6.0    -6.0    -6.0    -6.0
# I100067        -6.0    -6.0    -6.0    -6.0    -6.0    -6.0    -6.0    -6.0
# I100168        -6.0    -6.0    -6.0    -6.0    -6.0    -6.0    -6.0    -6.0
#
# ...

# %%
def silhouette_analysis(i,data): #몇개 cluster,입력데이터
  # Clustering
  km = KMeans(n_clusters=i,
            init='random',
            n_init=10,
            max_iter=300,
            tol=1e-04,
            random_state=0)
  y_km=km.fit_predict(data)

  # Evaluating silhouette coefficients
  from sklearn.metrics import silhouette_samples
  silhouette_vals=silhouette_samples(data,y_km, metric='euclidean')

  # Ploting
  from matplotlib import cm
  cluster_labels = np.unique(y_km)
  n_clusters = cluster_labels.shape[0]
  y_ax_lower, y_ax_upper = 0, 0
  yticks = []
  for i,c in enumerate(cluster_labels):
      c_silhouette_vals = silhouette_vals[y_km == c]
      c_silhouette_vals.sort()
      y_ax_upper += len(c_silhouette_vals)
      color = cm.jet(float(i)/n_clusters)
      plt.barh(range(y_ax_lower, y_ax_upper),
              c_silhouette_vals,
              height=1.0,
              edgecolor='none',
              color=color)
      yticks.append((y_ax_lower+y_ax_upper)/2.)
      y_ax_lower += len(c_silhouette_vals)

  # Ploting average of silhouette coefficients
  silhouette_avg = np.mean(silhouette_vals)
  plt.axvline(silhouette_avg,
            color="red",
            linestyle="--")

  # Layout
  plt.yticks(yticks, cluster_labels+1)
  plt.ylabel('Cluster')
  plt.xlabel('Silhouette coefficient')
  plt.tight_layout()
  plt.show()

# %%
#45초
silhouette_analysis(2,su1_table)

# %%
silhouette_analysis(3,su1_table)

# %%
silhouette_analysis(4,su1_table)

# %%
silhouette_analysis(5,su1_table)

# %%
silhouette_analysis(6,su1_table)

# %%
silhouette_analysis(7,su1_table)

# %%
#elbow method
distortions = []

#cluster의 개수별로 SSE 구해보자!
#어디까지 나눠야하는가?에 대한 판단은 정성적으로 

for i in range(1,11):
    km = KMeans(n_clusters=i,
               init='random',
               n_init=10,
               max_iter=300,
               random_state=0)
    km.fit(su1_table)
    distortions.append(km.inertia_)
distortions

import matplotlib.pyplot as plt
plt.plot(range(1,11), distortions, marker='o')

# %%
su1_table['mean_z_score']=su1_table.mean(axis='columns')
su1_table['y_km']=su1_kmeans4['y_km']
su1_table.head(3)
# Out:
#      3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 0  0.785218  0.481168  0.170512 -1.117303  0.000000 -0.667929 -0.824468
# 1  0.000000  0.583883  0.114975  0.053498  2.077496  0.000000 -0.247911
# 2  0.448712  0.326945 -0.775063  0.163261  0.000000 -0.091704  0.314965
#
#      3381_3    3381_4  3381_5  ...    3403_3    3403_4    3403_5    3404_1  \
# 0  0.107157  0.539246     0.0  ...  0.464646  0.137118  0.000000 -1.593239
# 1  0.466481  0.655537     0.0  ...  0.485794  0.123795 -0.284755  0.000000
# 2  0.557257  0.000000     0.0  ... -0.231018 -0.258156  0.000000 -0.076798
#
#      3404_2    3404_3    3404_4    3404_5  mean_z_score  y_km
# 0 -0.202572  0.448705 -0.291084 -1.395543     -0.128882     3
# 1  0.476071  0.318606 -0.175488  0.117922      0.192114     1
# 2  0.116851 -0.071692 -0.536725  0.000000     -0.228133     3
#
# [3 rows x 117 columns]

# %%
sns.scatterplot(x='mean_z_score',y='y_km',data=su1_table,hue='y_km')

# %% [markdown]
# ## EDA
# - 그룹별로 변별이 되는 문제는 뭘까?
# - 평균 z-score 높은 애들이 더 난이도 있는 문제를 푸는가?
# - 문제를 더 많이 푸는가?
# - 문제를 더 다양하게 푸는가?
# - 유료 결제 학원에 다니는가?

# %%
data = pd.read_csv('/content/drive/MyDrive/프리윌린/z_score_with_subject.csv')

# %%
su1_table["student_id"] = s1.loc[:,'student_id']

# %%
su1_table
# Out:
#          3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 0      0.785218  0.481168  0.170512 -1.117303  0.000000 -0.667929 -0.824468
# 1      0.000000  0.583883  0.114975  0.053498  2.077496  0.000000 -0.247911
# 2      0.448712  0.326945 -0.775063  0.163261  0.000000 -0.091704  0.314965
# 3      0.000000  0.000000  0.000000 -0.733134 -0.444662  0.785159 -0.531755
# 4      0.785218  0.000000  1.474754  0.979621  0.714375  0.000000  1.029385
# ...         ...       ...       ...       ...       ...       ...       ...
# 17438  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17439  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17440  0.000000  0.000000  1.474754 -2.141754  2.077496  0.000000  0.000000
# 17441  0.000000  0.000000  1.474754 -2.141754  2.077496  0.000000  0.000000
# 17442  0.000000  0.000000  1.474754 -2.141754  2.077496  0.000000  0.000000
#
# ...

# %%
su1_table.to_csv("su1_final.csv", index = False)

# %%
su1_merge_table=su1_table.loc[:,['student_id','y_km']]

# %%
data2=pd.merge(data,su1_merge_table,how='left',on='student_id')
data2.head()
# Out:
#    Unnamed: 0 student_id  problem_curriculum_id  level  count(problem_id)  \
# 0           0    I100008                   3308      1                 35
# 1           1    I100008                   3308      2                 26
# 2           2    I100008                   3308      3                 12
# 3           3    I100008                   3308      4                  9
# 4           4    I100008                   3309      1                338
#
#    none  correct  wrong  unknown       rate   Z-score              name  \
# 0     0       26      9        0  74.285714 -0.653638  곱셈 공식과 곱셈 공식의 변형
# 1     2       15      9        0  62.500000 -0.510792  곱셈 공식과 곱셈 공식의 변형
# 2     4        4      4        0  50.000000 -0.826631  곱셈 공식과 곱셈 공식의 변형
# 3     4        1      4        0  20.000000 -1.507341  곱셈 공식과 곱셈 공식의 변형
# 4   214      114     10        0  91.935484 -0.015597           다항식의 연산
#
#    parent3_id parent3_name  y_km
# 0        41.0      고등수학(상)   3.0
# ...

# %%
data2["try"] = data2["correct"] + data2["wrong"]

# %% [markdown]
# ### 0인 애들이 난이도 높은걸 많이 풀었는가? True

# %%
k=pd.pivot_table(data2,values='try',index='level',columns='y_km',aggfunc=sum,margins=True)
k=k/k.loc['All']*100
k
# Out:
# y_km          0.0         1.0         2.0         3.0         All
# level
# 1       19.338650   12.210157   25.939466   21.332738   18.492791
# 2       33.550848   28.493140   38.117262   36.783891   33.240804
# 3       28.849717   34.762548   27.204236   29.664070   30.154842
# 4       14.045947   19.751642    7.351768   10.193248   14.281133
# 5        4.214839    4.782513    1.387268    2.026053    3.830430
# All    100.000000  100.000000  100.000000  100.000000  100.000000

# %%
k.transpose().iloc[:4,:5].plot(kind='barh',figsize=(10,6),stacked=True,alpha=0.7)

# %% [markdown]
# ### 그룹을 구분짓는 주요 column은 무엇일까?
# - 전체 그룹을 구분짓는 주요 column은 지수, 로그 부분 즉. 교재 앞부분

# %%
su1_table.head()
# Out:
#      3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 0  0.785218  0.481168  0.170512 -1.117303  0.000000 -0.667929 -0.824468
# 1  0.000000  0.583883  0.114975  0.053498  2.077496  0.000000 -0.247911
# 2  0.448712  0.326945 -0.775063  0.163261  0.000000 -0.091704  0.314965
# 3  0.000000  0.000000  0.000000 -0.733134 -0.444662  0.785159 -0.531755
# 4  0.785218  0.000000  1.474754  0.979621  0.714375  0.000000  1.029385
#
#      3381_3    3381_4  3381_5  ...    3403_3    3403_4    3403_5    3404_1  \
# 0  0.107157  0.539246     0.0  ...  0.464646  0.137118  0.000000 -1.593239
# 1  0.466481  0.655537     0.0  ...  0.485794  0.123795 -0.284755  0.000000
# 2  0.557257  0.000000     0.0  ... -0.231018 -0.258156  0.000000 -0.076798
# 3  0.000000  0.000000     0.0  ... -0.113394 -2.234526  0.000000  0.729820
# 4  0.000000 -0.646925     0.0  ...  0.894199  1.145067 -1.784022  0.729820
#
#      3404_2    3404_3    3404_4    3404_5  mean_z_score  y_km
# ...

# %%
su1_table['y_km'].value_counts()
# Out:
# 0    9839
# 3    3797
# 1    2687
# 2    1120
# Name: y_km, dtype: int64

# %%
su1_table = su1_table.drop(['student_id'], axis = 1)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(random_state=42)
model.fit(su1_table.drop('y_km',axis=1),su1_table['y_km'])
# Out:
# RandomForestClassifier(random_state=42)

# %%
feat_imp=pd.DataFrame(model.feature_importances_,index=model.feature_names_in_,columns=['feature_importance'])
imp_sorted=feat_imp.sort_values(by='feature_importance',ascending=True)
imp_sorted[-20:].plot(kind='barh')

# %%
#0,1 그룹 비교
su1_10_table=su1_table[(su1_table['y_km']==0)|(su1_table['y_km']==1)]

# %%
su1_10_table.head()
# Out:
#      3380_1    3380_2    3380_3    3380_4    3380_5    3381_1    3381_2  \
# 1  0.000000  0.583883  0.114975  0.053498  2.077496  0.000000 -0.247911
# 3  0.000000  0.000000  0.000000 -0.733134 -0.444662  0.785159 -0.531755
# 4  0.785218  0.000000  1.474754  0.979621  0.714375  0.000000  1.029385
# 5  0.000000 -0.868809  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.000000  1.352315  0.915919  1.590667  0.000000  0.000000
#
#      3381_3    3381_4  3381_5  ...    3403_3    3403_4    3403_5   3404_1  \
# 1  0.466481  0.655537     0.0  ...  0.485794  0.123795 -0.284755  0.00000
# 3  0.000000  0.000000     0.0  ... -0.113394 -2.234526  0.000000  0.72982
# 4  0.000000 -0.646925     0.0  ...  0.894199  1.145067 -1.784022  0.72982
# 5  0.000000  0.000000     0.0  ...  0.000000  0.000000  0.000000  0.00000
# 6  0.000000  0.000000     0.0  ...  0.990728  0.063005  0.000000  0.00000
#
#      3404_2    3404_3    3404_4    3404_5  mean_z_score  y_km
# ...

# %%
model=RandomForestClassifier(random_state=42)
model.fit(su1_10_table.drop('y_km',axis=1),su1_10_table['y_km'])
feat_imp=pd.DataFrame(model.feature_importances_,index=model.feature_names_in_,columns=['feature_importance'])
imp_sorted=feat_imp.sort_values(by='feature_importance',ascending=True)
imp_sorted[-20:].plot(kind='barh')

# %% [markdown]
# ### 하나의 그룹을 변별하는 문제?

# %% [markdown]
# #### 잘하는애들

# %%
su1_1_table=su1_table[su1_table['y_km']==1]

# %%
su1_1_table=su1_1_table.drop(['mean_z_score','y_km'],axis=1)
su1_1_table.head(3)
# Out:
#      3380_1    3380_2    3380_3    3380_4    3380_5  3381_1    3381_2  \
# 1  0.000000  0.583883  0.114975  0.053498  2.077496     0.0 -0.247911
# 4  0.785218  0.000000  1.474754  0.979621  0.714375     0.0  1.029385
# 6  0.000000  0.000000  1.352315  0.915919  1.590667     0.0  0.000000
#
#      3381_3    3381_4  3381_5  ...    3403_1    3403_2    3403_3    3403_4  \
# 1  0.466481  0.655537     0.0  ... -0.238156  0.388670  0.485794  0.123795
# 4  0.000000 -0.646925     0.0  ...  0.740559  0.880554  0.894199  1.145067
# 6  0.000000  0.000000     0.0  ...  0.740559 -0.504290  0.990728  0.063005
#
#      3403_5   3404_1    3404_2    3404_3    3404_4    3404_5
# 1 -0.284755  0.00000  0.476071  0.318606 -0.175488  0.117922
# 4 -1.784022  0.72982  1.100338  0.000000  0.896182  0.000000
# 6  0.000000  0.00000  0.394595  0.448705  0.545916  0.000000
#
# [3 rows x 115 columns]

# %%
pca=PCA(n_components=10)
pca.fit(su1_1_table)
pca.explained_variance_ratio_*100
# Out:
# array([6.66500363, 5.70768441, 4.18026284, 3.04012457, 2.13876316,
#        1.8730577 , 1.78394031, 1.60936102, 1.53794595, 1.4948157 ])

# %%
su1_1_table_pca=pca.fit_transform(su1_1_table)

# %%
component_names = [f"PC{i+1}" for i in range(su1_1_table_pca.shape[1])]

loadings = pd.DataFrame(
    pca.components_.T,  # transpose the matrix of loadings
    columns=component_names,  # so the columns are the principal components
    index=su1_1_table.columns,  # and the rows are the original features
)
loadings
# Out:
#              PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 3380_1 -0.177836  0.042756 -0.087338 -0.021619 -0.061313 -0.007745  0.040802
# 3380_2 -0.031425  0.043205 -0.057603  0.013442 -0.092064 -0.135310  0.033297
# 3380_3 -0.078601  0.150670 -0.063283 -0.129282 -0.249937  0.030036 -0.148845
# 3380_4 -0.117682  0.227314 -0.005212 -0.178579 -0.359916  0.013869 -0.228898
# 3380_5 -0.027464  0.280054  0.156755 -0.001267 -0.270993 -0.097425 -0.229003
# ...          ...       ...       ...       ...       ...       ...       ...
# 3404_1 -0.022017 -0.000446 -0.085871  0.087508  0.028699 -0.044805 -0.091356
# 3404_2  0.015309  0.009820 -0.107537  0.138708  0.021206 -0.064198 -0.124253
# 3404_3 -0.049407  0.023102 -0.019602  0.074467 -0.018552 -0.151932 -0.023580
# 3404_4  0.108055  0.114032 -0.032557  0.086227  0.042503  0.108733 -0.028503
# 3404_5 -0.008176  0.049352 -0.002586  0.034366  0.036783 -0.070586 -0.011045
#
#              PC8       PC9      PC10
# ...

# %%
sns.scatterplot(x='PC1', y='PC2', data=loadings)
plt.plot([0,0],[0,0.25],color='red')
plt.plot([-0.4,0.2],[0,0],color='red')

# %%
loadings.sort_values(by='PC1',ascending=False).head(20)
# Out:
#              PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 3402_5  0.185274  0.077500  0.044257  0.084118  0.081120  0.061943  0.038577
# 3389_5  0.172999  0.104139 -0.019733 -0.038387  0.064124 -0.037224 -0.003893
# 3386_4  0.167569  0.066315 -0.003660  0.036174 -0.127635 -0.059935  0.084361
# 3400_4  0.164761  0.079994 -0.007170  0.152450  0.018205 -0.008589  0.073187
# 3391_5  0.158082  0.104294  0.003995 -0.078303  0.047289  0.033021  0.028368
# 3399_4  0.144495  0.153125  0.031436  0.043837  0.042473  0.100844 -0.007619
# 3403_5  0.142420  0.071806  0.016719  0.062530  0.054007 -0.050586  0.119884
# 3384_5  0.122909  0.214332  0.052604 -0.013792 -0.171130 -0.187132 -0.026062
# 3386_3  0.120524  0.041537 -0.097745  0.002196 -0.017137 -0.261233  0.013867
# 3393_4  0.112553  0.132781 -0.024546 -0.061475  0.057633 -0.022608 -0.128034
# 3385_4  0.110215  0.126897 -0.028824  0.041914 -0.062092  0.021198  0.227971
# ...

# %%
#우리 원래 column개수 만큼 주성분 나온다
#sum(각 주성분이 설명하는 분산* 해당 주성분 만들때 기여한 정도)
#클수록 해당 집단을 잘 변별하는 주요 문제이지 않을까? 문제 추천 모델!!

# %% [markdown]
# #### 못하는 애들

# %%
su1_2_table=su1_table[su1_table['y_km']==2]
su1_2_table=su1_2_table.drop(['mean_z_score','y_km'],axis=1)
su1_2_table.head(3)
# Out:
#      3380_1    3380_2    3380_3    3380_4  3380_5    3381_1    3381_2  3381_3  \
# 19 -1.73858 -2.805732  1.474754 -0.726394     0.0 -1.757745 -2.092894     0.0
# 21  0.00000  0.000000 -1.382156  0.000000     0.0 -0.910110  0.000000     0.0
# 45 -1.10763  0.000000 -2.810611  0.000000     0.0  0.000000 -1.312324     0.0
#
#     3381_4  3381_5  ...   3403_1    3403_2    3403_3  3403_4  3403_5  \
# 19     0.0     0.0  ...  0.33721  0.237591 -1.269474     0.0     0.0
# 21     0.0     0.0  ...  0.00000 -1.119776  0.000000     0.0     0.0
# 45     0.0     0.0  ...  0.00000 -2.119941  1.331706     0.0     0.0
#
#       3404_1    3404_2  3404_3    3404_4  3404_5
# 19 -0.722092 -0.028851     0.0  1.182764     0.0
# 21  0.729820 -0.405247     0.0  0.000000     0.0
# 45  0.000000  0.000000     0.0 -2.256215     0.0
#
# [3 rows x 115 columns]

# %%
pca=PCA(n_components=10)
pca.fit(su1_2_table)
pca.explained_variance_ratio_*100
# Out:
# array([8.15729196, 4.88643558, 3.66901978, 3.31989398, 3.13388183,
#        2.59590757, 2.39818101, 2.35313169, 1.99776349, 1.97674011])

# %%
su1_2_table_pca=pca.fit_transform(su1_2_table)
component_names = [f"PC{i+1}" for i in range(su1_2_table_pca.shape[1])]

loadings = pd.DataFrame(
    pca.components_.T,  # transpose the matrix of loadings
    columns=component_names,  # so the columns are the principal components
    index=su1_2_table.columns,  # and the rows are the original features
)
loadings
# Out:
#              PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 3380_1  0.116104 -0.135252  0.039106  0.039239 -0.113094  0.127154  0.049009
# 3380_2  0.096302 -0.161728  0.113238  0.037288  0.061413  0.176177  0.087328
# 3380_3  0.131029 -0.108108  0.080102 -0.022591  0.164764  0.097546  0.025989
# 3380_4  0.107420 -0.054676 -0.017849 -0.048722  0.148215 -0.097734 -0.071725
# 3380_5  0.032216 -0.017837  0.005125 -0.016101  0.036507  0.011525  0.037377
# ...          ...       ...       ...       ...       ...       ...       ...
# 3404_1 -0.163538 -0.113101  0.031750 -0.038123 -0.059689 -0.004865  0.028877
# 3404_2 -0.128873 -0.106760  0.036715  0.011564 -0.004758  0.015753  0.150396
# 3404_3 -0.012914 -0.016458  0.071757  0.037438  0.050123 -0.047431  0.100061
# 3404_4  0.014955 -0.017137  0.018291  0.036025  0.129392 -0.037335  0.057539
# 3404_5 -0.000807 -0.005269  0.009231  0.006690  0.017632 -0.002072 -0.002544
#
#              PC8       PC9      PC10
# ...

# %%
sns.scatterplot(x='PC1', y='PC2', data=loadings)
plt.plot([0,0],[-0.25,0.05],color='red')
plt.plot([-0.3,0.2],[0,0],color='red')

# %%
loadings.sort_values(by='PC1',ascending=False).head(20)
# Out:
#              PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 3392_2  0.212236 -0.194164 -0.081032 -0.074325  0.012784 -0.085031  0.043500
# 3392_3  0.196346 -0.177116 -0.062551 -0.041028  0.043094 -0.079268  0.023840
# 3390_3  0.177055 -0.161029 -0.097008 -0.028785  0.075128 -0.005070 -0.091462
# 3389_2  0.165409 -0.186636 -0.266179  0.048034 -0.100221 -0.106597 -0.192259
# 3394_2  0.163951 -0.165943 -0.117730 -0.073471 -0.009686 -0.178141  0.037497
# 3391_2  0.163247 -0.154053 -0.036269 -0.052245 -0.128898  0.180042  0.165571
# 3390_2  0.142163 -0.252703 -0.101893 -0.041898 -0.049208  0.065720  0.087599
# 3380_3  0.131029 -0.108108  0.080102 -0.022591  0.164764  0.097546  0.025989
# 3391_3  0.127467 -0.101032 -0.023441 -0.039649  0.101636 -0.117508  0.041663
# 3389_3  0.119642 -0.197802 -0.033849 -0.019384  0.032514  0.030804  0.035688
# 3380_1  0.116104 -0.135252  0.039106  0.039239 -0.113094  0.127154  0.049009
# ...
